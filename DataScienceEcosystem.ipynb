# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ![image.png](attachment:b5fb80f3-2fdb-49d1-b685-90e95f97dd39.png)

# %% [markdown]
# ![image.png](attachment:c0324e68-ed60-4780-9d9c-832e13ec1870.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:d0e42cde-8345-40f9-a105-f311a6942270.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](attachment:81b3449e-e35a-4a9e-bf1b-5546a68041c0.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ![image.png](attachment:2fc911e9-50c5-493c-a6ee-1719b4dc91aa.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# ![image.png](attachment:13b03d09-89cf-49ea-9127-064cfa7da358.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | Apache Zeppelin    |
# | RStudio            |

# %% [markdown]
# ![image.png](attachment:35e58d31-0515-429a-8bc3-64120d7dd491.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![image.png](attachment:162bc3f2-879a-4319-9728-298cd1af3fee.png)

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:603e46de-2565-4390-9b90-024bc10aa6a0.png)

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours   = minutes/60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](attachment:7ed7a6d4-a55c-4e84-8280-b1d7515ce4e0.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries for Data Science
# - Provide examples of arithmetic expressions in Python
# - Create a table for open-source Data Science tools

# %% [markdown]
# ![image.png](attachment:09389ec0-24d4-441d-873b-25bb1eacca7f.png)

# %% [markdown]
# ## Author
# Faiqul Fikri

# %% [markdown]
# ![image.png](attachment:8b60e65f-bb63-4e95-9c54-27a927e2dbfc.png)

# %% [markdown]
# ![image.png](attachment:00864933-0706-4679-91a5-cb81848ba330.png)
